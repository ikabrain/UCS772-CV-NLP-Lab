# %% [markdown]
#
#          Term Frequency(TF) = [number of times word appeared / total no of words in a document]
#
# - TF[0,1].
# TF close to 1 If a word occurs more number of times
#
#          Inverse Document Frequency(IDF) = [log(Total number of documents / number of documents that contains the word)]
#
# - In IDF approaches 0 , if a word is common across all documents,
#
#          TF-IDF = Term Frequency(TF) * Inverse Document Frequency(IDF)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corpus = ["I am a large language model",
  "massive text data"," under development",
  "best to help."
]

# %%
v = TfidfVectorizer()
v.fit(corpus)
transform_output = v.transform(corpus)

# %%
print(v.vocabulary_)
# Out:
# {'am': 0, 'large': 6, 'language': 5, 'model': 8, 'massive': 7, 'text': 9, 'data': 2, 'under': 11, 'development': 3, 'best': 1, 'to': 10, 'help': 4}

# %%
print(transform_output.toarray())
# Out:
# [[0.5        0.         0.         0.         0.         0.5
#   0.5        0.         0.5        0.         0.         0.        ]
#  [0.         0.         0.57735027 0.         0.         0.
#   0.         0.57735027 0.         0.57735027 0.         0.        ]
#  [0.         0.         0.         0.70710678 0.         0.
#   0.         0.         0.         0.         0.         0.70710678]
#  [0.         0.57735027 0.         0.         0.57735027 0.
#   0.         0.         0.         0.         0.57735027 0.        ]]

# %%
all_feature_names = v.get_feature_names_out()

for word in all_feature_names:
    indx = v.vocabulary_.get(word)
    idf_score = v.idf_[indx]
    print(f"{word} : {idf_score}")
# Out:
# am : 1.916290731874155
# best : 1.916290731874155
# data : 1.916290731874155
# development : 1.916290731874155
# help : 1.916290731874155
# language : 1.916290731874155
# large : 1.916290731874155
# massive : 1.916290731874155
# model : 1.916290731874155
# text : 1.916290731874155
# to : 1.916290731874155
# under : 1.916290731874155
